# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# example of fitting a model on the scaled dataset
from pickle import dump
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from pickle import load

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import *
from IPython.html import widgets
plt.style.use("ggplot")
# Out:
# C:\Users\javie\Anaconda3\lib\site-packages\IPython\html.py:12: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   warn("The `IPython.html` package has been deprecated since IPython 4.0. "

# %%
import ipywidgets as widgets
from ipywidgets import HTML
import base64
import csv
from io import StringIO
import os
from IPython.display import Image, display, HTML, Markdown, clear_output
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

import cufflinks as cf
cf.go_offline(connected=True)
cf.set_config_file(colorscale='plotly', world_readable=True)
# Show all code cells outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
def Masterized_detect_numbers_in_strings(string):#solo el primer numero
    import re
    num = [int(float(string)) for string in re.findall(r'-?\d+\.?\d*', string)]
    return num[0]#solo el primer numero
from datetime import date
d0 = date(2017, 8, 18)
d1 = date(2017, 10, 26)
delta = d1 - d0

#Masterized_detect_numbers_in_strings(str(calendar_INICIO.value- d0))

# %%
dfHorario = pd.DataFrame(
    {'Hora': ["10:00 a 11:00","11:00 a 12:00","12:00 a 13:00","13:00 a 14:00","14:00 a 15:00","15:00 a 16:00","16:00 a 17:00","17:00 a 18:00","18:00 a 19:00","19:00 a 20:00","20:00 a 21:00","21:00 a 22:00","22:00 a 23:00","23:00 a 24:00"],
     'Lunes': ["Lengua","Lengua","Mates","Mates","////","////","////","Historia","Historia","////","////","////","////","////"],
     'Martes': ["Lengua","Lengua","Mates","Mates","////","////","////","Fisica","Fisica","////","////","////","////","////"],
     'Miercoles': ["Lengua","////","////","Mates","////","////","////","Historia","Historia","////","////","////","////","////"],
     'Jueves': ["Historia","Historia","////","////","////","////","////","Dibujo","Dibujo","////","////","////","////","////"],
     'Viernes': ["Lengua","Lengua","Mates","Mates","////","////","////","Historia","Historia","////","////","////","////","////"],
     'Sabado': ["////","////","Dibujo","Dibujo","////","////","////","Fisica","Fisica","////","////","////","////","////"],
     'Domingo': ["Lengua","////","Mates","////","////","////","////","////","Historia","Ingles","////","////","////","////"],
    })
dfHorario
# Out:
#              Hora     Lunes  Martes Miercoles    Jueves   Viernes  Sabado  \
# 0   10:00 a 11:00    Lengua  Lengua    Lengua  Historia    Lengua    ////
# 1   11:00 a 12:00    Lengua  Lengua      ////  Historia    Lengua    ////
# 2   12:00 a 13:00     Mates   Mates      ////      ////     Mates  Dibujo
# 3   13:00 a 14:00     Mates   Mates     Mates      ////     Mates  Dibujo
# 4   14:00 a 15:00      ////    ////      ////      ////      ////    ////
# 5   15:00 a 16:00      ////    ////      ////      ////      ////    ////
# 6   16:00 a 17:00      ////    ////      ////      ////      ////    ////
# 7   17:00 a 18:00  Historia  Fisica  Historia    Dibujo  Historia  Fisica
# 8   18:00 a 19:00  Historia  Fisica  Historia    Dibujo  Historia  Fisica
# 9   19:00 a 20:00      ////    ////      ////      ////      ////    ////
# 10  20:00 a 21:00      ////    ////      ////      ////      ////    ////
# 11  21:00 a 22:00      ////    ////      ////      ////      ////    ////
# ...

# %%
text = widgets.Text(
       value='',
       description='Nombre', )
calendar_INICIO = widgets.DatePicker(
           description='Inicio del Horario')
calendar_Examenes = widgets.DatePicker(
           description='Fecha de examenes')


layout = widgets.Layout(width='auto', height='auto') #set width and height
style = {'description_width': '300px'}

StartHorario_hor = widgets.BoundedIntText(
    value=9,
    min=6,
    max=15,
    step=1,
    description='Hora de comienzo a estudiar:',
    disabled=False)

como_se_te_da_Lengua = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Mates = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Ingles = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Historia = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Biologia = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Quimica = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Fisica = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Dibujo = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Mates_Sociales = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Economia = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)

como_se_te_da_Geografia = widgets.BoundedIntText(
    value=3,
    min=1,
    max=5,
    step=1,
    description='del 1 al 5, ¿Como de bien se te da? :',
    style=style,
    layout=layout,
    disabled=False)
     
         
bach = widgets.Dropdown(
       options=['Sociales', 'Tecnologico', 'Biosanitario'],
       value=None,
       description='Bachillerato:')
checkbox = widgets.Checkbox(
           description='Check to invert',)
Mates = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Mates:',
    disabled=False,
)
Lengua = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Lengua:',
    disabled=False
)
Historia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Historia:',
    disabled=False
)
Ingles = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Ingles:',
    disabled=False
)
Mates_sociales = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Mates_sociales:',
    disabled=False
)

Geografia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Geografia:',
    disabled=False
)
Economia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Economia:',
    disabled=False
)
Dibujo = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Dibujo:',
    disabled=False
)
Fisica = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Fisica:',
    disabled=False
)
Biologia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Biologia:',
    disabled=False
)
Quimica = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Quimica:',
    disabled=False
)



text
calendar_INICIO
StartHorario_hor
calendar_Examenes
bach
button = widgets.Button(description='Confirmar Bachillerato')
button2 = widgets.Button(description='Confirmar Notas')
button3 = widgets.Button(description="Obtener Perfil y Generar Horario",style = {'button_color': '#7DF0BF'},layout=Layout(width='30%', height='30px'))
out = widgets.Output()
nptas=[]
def on_button_clicked3(_):
     
    with out:
        if len(nptas)!=0 and text.value != None and calendar_INICIO.value != None and calendar_Examenes.value != None and StartHorario_hor.value != None:
            print("")
            print("")
            if (bach.value)=="Sociales":
                dx= pd.DataFrame(np.asarray(nptas[-12:]).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                print("Tus notas: ")
                print(dx)
                dx["tipo_bachillerato-Sociales"]=1
                print("")
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato

                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("\033[1m" +"Tiempo de estudio "+str(Masterized_detect_numbers_in_strings(str(calendar_Examenes.value-calendar_INICIO.value)))+" días"+ "\033[0m")
                print("")
                print("\033[1m" +"En base a tus notas tu cluster es: "+str(pcadf["predicted_cluster"].values.tolist()[0])+ "\033[0m")
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfSOCIALES.csv")
                print(dx[dx["cluster"]==float(pcadf["predicted_cluster"].values.tolist()[0])])
                print("")
                print("\033[1m" +"Descargue su horario personalizado!"+"\033[1m")

                res2 = dfHorario.columns.to_frame().T.append(dfHorario, ignore_index=True)
                res2.columns = range(len(res2.columns))
                filename = 'Tu_horario.csv'
                mylist = res2.values.tolist()
                f = StringIO()
                csv.writer(f).writerows(mylist)

                b64 = base64.b64encode(f.getvalue().encode())
                payload = b64.decode()

                #BUTTONS
                html_buttons = '''<html>
                <head>
                <meta name="viewport" content="width=device-width, initial-scale=1">
                </head>
                <body>
                <a download="{filename}" href="data:text/csv;base64,{payload}" download>
                <button class="p-Widget jupyter-widgets jupyter-button widget-button mod-warning">Download File</button>
                </a>
                </body>
                </html>
                '''

                html_button = html_buttons.format(payload=payload,filename=filename)
                display(HTML(html_button))
                
            elif (bach.value)=="Tecnologico":
                dx= pd.DataFrame(np.asarray(nptas[-12:]).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                print("Tus notas: ")
                print(dx)
                dx["tipo_bachillerato-Tecnologico"]=1
                print("")
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato

                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("\033[1m" +"Tiempo de estudio "+str(Masterized_detect_numbers_in_strings(str(calendar_Examenes.value-calendar_INICIO.value)))+" días"+ "\033[0m")
                print("")
                print("\033[1m" +"En base a tus notas tu cluster es: "+str(pcadf["predicted_cluster"].values.tolist()[0])+ "\033[0m")
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfCIENCIAS.csv")
                print(dx[dx["cluster"]==pcadf["predicted_cluster"].values.tolist()[0]])
                print("")
                print("\033[1m" +"Descargue su horario personalizado!"+"\033[1m")

                res2 = dfHorario.columns.to_frame().T.append(dfHorario, ignore_index=True)
                res2.columns = range(len(res2.columns))
                filename = 'Tu_horario.csv'
                mylist = res2.values.tolist()
                f = StringIO()
                csv.writer(f).writerows(mylist)

                b64 = base64.b64encode(f.getvalue().encode())
                payload = b64.decode()

                #BUTTONS
                html_buttons = '''<html>
                <head>
                <meta name="viewport" content="width=device-width, initial-scale=1">
                </head>
                <body>
                <a download="{filename}" href="data:text/csv;base64,{payload}" download>
                <button class="p-Widget jupyter-widgets jupyter-button widget-button mod-warning">Download File</button>
                </a>
                </body>
                </html>
                '''

                html_button = html_buttons.format(payload=payload,filename=filename)
                display(HTML(html_button))
            elif (bach.value)=="Biosanitario":

                dx= pd.DataFrame(np.asarray(nptas[-12:]).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                print("Tus notas: ")
                print(dx)
                dx["tipo_bachillerato-Sanitario"]=1
                print("")
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato

                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("\033[1m" +"Tiempo de estudio "+str(Masterized_detect_numbers_in_strings(str(calendar_Examenes.value-calendar_INICIO.value)))+" días"+ "\033[0m")
                print("")
                print("\033[1m" + "En base a tus notas tu cluster es: " +str(pcadf["predicted_cluster"].values.tolist()[0])+ "\033[0m")
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfCIENCIAS.csv")
                print(dx[dx["cluster"]==pcadf["predicted_cluster"].values.tolist()[0]])
                print("")
                print("\033[1m" +"Descargue su horario personalizado!"+"\033[1m")

                res2 = dfHorario.columns.to_frame().T.append(dfHorario, ignore_index=True)
                res2.columns = range(len(res2.columns))
                filename = 'Tu_horario.csv'
                mylist = res2.values.tolist()
                f = StringIO()
                csv.writer(f).writerows(mylist)

                b64 = base64.b64encode(f.getvalue().encode())
                payload = b64.decode()

                #BUTTONS
                html_buttons = '''<html>
                <head>
                <meta name="viewport" content="width=device-width, initial-scale=1">
                </head>
                <body>
                <a download="{filename}" href="data:text/csv;base64,{payload}" download>
                <button class="p-Widget jupyter-widgets jupyter-button widget-button mod-warning">Download File</button>
                </a>
                </body>
                </html>
                '''

                html_button = html_buttons.format(payload=payload,filename=filename)
                display(HTML(html_button))
                
            
        else:
            print("\033[1m" +"Confirma todos los inputs"+"\033[1m")
        
def on_button_clicked2(_):

      # "linking function with output"
    with out:
          # what happens when we press the button
        if (bach.value)=="Sociales":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates_sociales.value,"Mates_sociales"])
            nptas.extend([Economia.value,"Economia"])
            nptas.extend([Geografia.value,"Geografia"])
            nptas.extend([Ingles.value,"Ingles"])
            print("Notas Añadidas")

        elif (bach.value)=="Tecnologico":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates.value,"Mates"])
            nptas.extend([Fisica.value,"Fisica"])
            nptas.extend([Dibujo.value,"Dibujo"])
            nptas.extend([Ingles.value,"Ingles"])
            print("Notas Añadidas")

        elif (bach.value)=="Biosanitario":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates.value,"Mates"])
            nptas.extend([Biologia.value,"Biologia"])
            nptas.extend([Quimica.value,"Quimica"])
            nptas.extend([Ingles.value,"Ingles"])
            print("Notas Añadidas")
       
#linking button and function together using a button's method

def on_button_clicked(_):
      # "linking function with output"
    with out:
          # what happens when we press the button
            clear_output()
            if bach.value=="Sociales":
                #display(Lengua)
                display(widgets.HBox((Lengua, como_se_te_da_Lengua)))
                display(widgets.HBox((Historia, como_se_te_da_Historia)))
                display(widgets.HBox((Mates_sociales, como_se_te_da_Mates_Sociales)))
                display(widgets.HBox((Economia, como_se_te_da_Economia)))
                display(widgets.HBox((Geografia, como_se_te_da_Geografia)))
                display(widgets.HBox((Ingles, como_se_te_da_Ingles)))
                
                
                return (bach.value)
            elif bach.value=="Tecnologico":
                display(widgets.HBox((Lengua, como_se_te_da_Lengua)))
                display(widgets.HBox((Historia, como_se_te_da_Historia)))
                display(widgets.HBox((Mates, como_se_te_da_Mates)))
                display(widgets.HBox((Fisica, como_se_te_da_Fisica)))
                display(widgets.HBox((Dibujo,como_se_te_da_Dibujo)))
                display(widgets.HBox((Ingles, como_se_te_da_Ingles)))

                return (bach.value)
            elif bach.value=="Biosanitario":
                display(widgets.HBox((Lengua, como_se_te_da_Lengua)))
                display(widgets.HBox((Historia, como_se_te_da_Historia)))
                display(widgets.HBox((Mates, como_se_te_da_Mates)))
                display(widgets.HBox((Biologia, como_se_te_da_Biologia)))
                display(widgets.HBox((Quimica, como_se_te_da_Quimica)))
                display(widgets.HBox((Ingles, como_se_te_da_Ingles)))
                
                return (bach.value)
    
# linking button and function together using a button's method
button.on_click(on_button_clicked)
button2.on_click(on_button_clicked2)
button3.on_click(on_button_clicked3)
# displaying button and its output together
widgets.VBox([button,out])
widgets.VBox([button2])
widgets.VBox([button3])
x=widgets.VBox([out])
# Out:
# Text(value='', description='Nombre')
# DatePicker(value=None, description='Inicio del Horario')
# BoundedIntText(value=9, description='Hora de comienzo a estudiar:', max=15, min=6)
# DatePicker(value=None, description='Fecha de examenes')
# Dropdown(description='Bachillerato:', options=('Sociales', 'Tecnologico', 'Biosanitario'), value=None)
# ...

# %%
from ipywidgets import HTML
import base64
import csv
from io import StringIO
res2 = dfHorario.columns.to_frame().T.append(dfHorario, ignore_index=True)
res2.columns = range(len(res2.columns))
filename = 'res.csv'
mylist = res2.values.tolist()
f = StringIO()
csv.writer(f).writerows(mylist)

b64 = base64.b64encode(f.getvalue().encode())
payload = b64.decode()

#BUTTONS
html_buttons = '''<html>
<head>
<meta name="viewport" content="width=device-width, initial-scale=1">
</head>
<body>
<a download="{filename}" href="data:text/csv;base64,{payload}" download>
<button class="p-Widget jupyter-widgets jupyter-button widget-button mod-warning">Download File</button>
</a>
</body>
</html>
'''

html_button = html_buttons.format(payload=payload,filename=filename)
display(HTML(html_button))
# Out:
# HTML(value='<html>\n<head>\n<meta name="viewport" content="width=device-width, initial-scale=1">\n</head>\n<bo…

# %%
from IPython.display import display

import base64

res = df3

#FILE
filename = 'res.csv'
b64 = base64.b64encode(res.encode())
payload = b64.decode()

#BUTTONS
html_buttons = '''<html>
<head>
<meta name="viewport" content="width=device-width, initial-scale=1">
</head>
<body>
<a download="{filename}" href="data:text/csv;base64,{payload}" download>
<button class="p-Widget jupyter-widgets jupyter-button widget-button mod-warning">Download File</button>
</a>
</body>
</html>
'''

html_button = html_buttons.format(payload=payload,filename=filename)
display(HTML(html_button))
# Out:
# HTML(value='<html>\n<head>\n<meta name="viewport" content="width=device-width, initial-scale=1">\n</head>\n<bo…

# %%
"""StartHorario_min = widgets.BoundedIntText(
    value=5,
    min=6,
    max=15.0,
    step=1,
    description='Hora de comienzo a estudiar:',
    disabled=False,
)"""

# %%
nptas[-10:]
# Out:
# [5.0, 'Historia', 5.0, 'Mates', 5.0, 'Fisica', 5.0, 'Dibujo', 5.0, 'Ingles']

# %%
23	7.40	8.10	5.56	5.78	5.35	7.65

# %%
text = widgets.Text(
       value='',
       description='Name', )
calendar_INICIO = widgets.DatePicker(
           description='Select Date')
calendar_Examenes = widgets.DatePicker(
           description='Select Date')


     
         
bach = widgets.Dropdown(
       options=['Sociales', 'Tecnologico', 'Biosanitario'],
       value=None,
       description='Bachillerato:')
checkbox = widgets.Checkbox(
           description='Check to invert',)
Mates = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Mates:',
    disabled=False,
)
Lengua = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Lengua:',
    disabled=False
)
Historia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Historia:',
    disabled=False
)
Ingles = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Ingles:',
    disabled=False
)
Mates_sociales = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Mates_sociales:',
    disabled=False
)

Geografia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Geografia:',
    disabled=False
)
Economia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Economia:',
    disabled=False
)
Dibujo = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Dibujo:',
    disabled=False
)
Fisica = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Fisica:',
    disabled=False
)
Biologia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Biologia:',
    disabled=False
)
Quimica = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Quimica:',
    disabled=False
)



text
calendar_INICIO
calendar_Examenes
bach
button = widgets.Button(description='Confirmar Bachillerato')
button2 = widgets.Button(description='Confirmar Notas')
button3 = widgets.Button(description='Obtener Perfil')
out = widgets.Output()
nptas=[]
def on_button_clicked3(_):
     
    with out:
        if len(nptas)!=0:
            print("")
            print("Evaluando")
            if (bach.value)=="Sociales":
                dx= pd.DataFrame(np.asarray(nptas).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                dx["tipo_bachillerato-Sociales"]=1
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato

                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("En base a tus notas tu cluster es: ",pcadf["predicted_cluster"].values.tolist()[0])
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfSOCIALES.csv")
                print(dx[dx["cluster"]==float(pcadf["predicted_cluster"].values.tolist()[0])])
                
            elif (bach.value)=="Tecnologico":
                dx= pd.DataFrame(np.asarray(nptas).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                dx["tipo_bachillerato-Tecnologico"]=1
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato

                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("En base a tus notas tu cluster es: ",pcadf["predicted_cluster"].values.tolist()[0])
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfCIENCIAS.csv")
                print(dx[dx["cluster"]==pcadf["predicted_cluster"].values.tolist()[0]])
            elif (bach.value)=="Biosanitario":

                dx= pd.DataFrame(np.asarray(nptas).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                dx["tipo_bachillerato-Sanitario"]=1
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato

                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("En base a tus notas tu cluster es: ",pcadf["predicted_cluster"].values.tolist()[0])
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfCIENCIAS.csv")
                print(dx[dx["cluster"]==pcadf["predicted_cluster"].values.tolist()[0]])
            
        else:
            print("Confirma todos los inputs")
        
def on_button_clicked2(_):

      # "linking function with output"
    with out:
          # what happens when we press the button
        if (bach.value)=="Sociales":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates_sociales.value,"Mates_sociales"])
            nptas.extend([Economia.value,"Economia"])
            nptas.extend([Geografia.value,"Geografia"])
            nptas.extend([Ingles.value,"Ingles"])

        elif (bach.value)=="Tecnologico":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates.value,"Mates"])
            nptas.extend([Fisica.value,"Fisica"])
            nptas.extend([Dibujo.value,"Dibujo"])
            nptas.extend([Ingles.value,"Ingles"])

        elif (bach.value)=="Biosanitario":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates.value,"Mates"])
            nptas.extend([Biologia.value,"Biologia"])
            nptas.extend([Quimica.value,"Quimica"])
            nptas.extend([Ingles.value,"Ingles"])
       
#linking button and function together using a button's method

def on_button_clicked(_):
      # "linking function with output"
    with out:
          # what happens when we press the button
            clear_output()
            if bach.value=="Sociales":
                display(Lengua)
                display(Historia)
                display(Mates_sociales)
                display(Economia)
                display(Geografia)
                display(Ingles)
                
                return (bach.value)
            elif bach.value=="Tecnologico":
                display(Lengua)
                display(Historia)
                display(Mates)
                display(Fisica)
                display(Dibujo)
                display(Ingles)
                
                return (bach.value)
            elif bach.value=="Biosanitario":
                display(Lengua)
                display(Historia)
                display(Mates)
                display(Biologia)
                display(Quimica)
                display(Ingles)
                
                return (bach.value)
    
# linking button and function together using a button's method
button.on_click(on_button_clicked)
button2.on_click(on_button_clicked2)
button3.on_click(on_button_clicked3)
# displaying button and its output together
widgets.VBox([button,out])
widgets.VBox([button2])
widgets.VBox([button3])
x=widgets.VBox([out])

# %%
text = widgets.Text(
       value='',
       description='Name', )
calendar_INICIO = widgets.DatePicker(
           description='Select Date')
calendar_Examenes = widgets.DatePicker(
           description='Select Date')


     
         
bach = widgets.Dropdown(
       options=['Sociales', 'Tecnologico', 'Biosanitario'],
       value=None,
       description='Bachillerato:')
checkbox = widgets.Checkbox(
           description='Check to invert',)
Mates = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Mates:',
    disabled=False,
)
Lengua = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Lengua:',
    disabled=False
)
Historia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Historia:',
    disabled=False
)
Ingles = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Ingles:',
    disabled=False
)
Mates_sociales = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Mates_sociales:',
    disabled=False
)

Geografia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Geografia:',
    disabled=False
)
Economia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Economia:',
    disabled=False
)
Dibujo = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Dibujo:',
    disabled=False
)
Fisica = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Fisica:',
    disabled=False
)
Biologia = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Biologia:',
    disabled=False
)
Quimica = widgets.BoundedFloatText(
    value=5,
    min=0,
    max=10.0,
    step=0.01,
    description='Nota Quimica:',
    disabled=False
)



text
calendar_INICIO
calendar_Examenes
bach
button = widgets.Button(description='Confirmar Bachillerato')
button2 = widgets.Button(description='Confirmar Notas')
button3 = widgets.Button(description='Obtener Perfil')
out = widgets.Output()
nptas=[]
def on_button_clicked3(_):
     
    with out:
        if len(nptas)!=0:
            print("")
            print("Evaluando")
            if (bach.value)=="Sociales":
                dx= pd.DataFrame(np.asarray(nptas).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                dx["tipo_bachillerato-Sociales"]=1
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato

                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("En base a tus notas tu cluster es: ",pcadf["predicted_cluster"].values.tolist()[0])
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfSOCIALES.csv")
                print(dx[dx["cluster"]==float(pcadf["predicted_cluster"].values.tolist()[0])])
            elif (bach.value)=="Tecnologico":
                dx= pd.DataFrame(np.asarray(nptas).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                dx["tipo_bachillerato-Tecnologico"]=1
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).head(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato
                print(data)
                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("En base a tus notas tu cluster es: ",pcadf["predicted_cluster"].values.tolist()[0])
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfCIENCIAS.csv")
                print(dx[dx["cluster"]==pcadf["predicted_cluster"].values.tolist()[0]])
            elif (bach.value)=="Biosanitario":

                dx= pd.DataFrame(np.asarray(nptas).reshape(-1,2))
                dx=dx.set_index(1).T
                notas=dx.iloc[0].values.tolist()
                notas = [float(x) for x in notas]
                media=sum(notas)/len(notas)
                dx["media_troncales"]=media
                dx["tipo_bachillerato-Sanitario"]=1
                df1=pd.read_csv("df_BACH__manerauno.csv")
                col=df1.columns.tolist()[9:]
                df1=df1[col]
                df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
                cols = df2.columns.tolist()
                df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
                data=(df2.to_numpy())

                data=data.reshape(1, -1)#si solo hay un dato
                data=np.nan_to_num(data)
                #data=data.reshape(1, -1)#si solo hay un dato
                print(data)
                pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
                pcadf = pd.DataFrame(
                    pipe["preprocessor"].transform(data),
                    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
                )

                pcadf["predicted_cluster"] = pipe.predict(data)
                print("En base a tus notas tu cluster es: ",pcadf["predicted_cluster"].values.tolist()[0])
                print("Caracteristicas de ese cluster: ")
                dx=pd.read_csv("Clusteres_dfCIENCIAS.csv")
                print(dx[dx["cluster"]==float(pcadf["predicted_cluster"].values.tolist()[0])])
            
        else:
            print("Confirma todos los inputs")
        
def on_button_clicked2(_):

      # "linking function with output"
    with out:
          # what happens when we press the button
        if (bach.value)=="Sociales":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates_sociales.value,"Mates_sociales"])
            nptas.extend([Economia.value,"Economia"])
            nptas.extend([Geografia.value,"Geografia"])
            nptas.extend([Ingles.value,"Ingles"])

        elif (bach.value)=="Tecnologico":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates.value,"Mates"])
            nptas.extend([Fisica.value,"Fisica"])
            nptas.extend([Dibujo.value,"Dibujo"])
            nptas.extend([Ingles.value,"Ingles"])

        elif (bach.value)=="Biosanitario":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates.value,"Mates"])
            nptas.extend([Biologia.value,"Biologia"])
            nptas.extend([Quimica.value,"Quimica"])
            nptas.extend([Ingles.value,"Ingles"])
       
#linking button and function together using a button's method

def on_button_clicked(_):
      # "linking function with output"
    with out:
          # what happens when we press the button
            clear_output()
            if bach.value=="Sociales":
                display(Lengua)
                display(Historia)
                display(Mates_sociales)
                display(Economia)
                display(Geografia)
                display(Ingles)
                
                return (bach.value)
            elif bach.value=="Tecnologico":
                display(Lengua)
                display(Historia)
                display(Mates)
                display(Fisica)
                display(Dibujo)
                display(Ingles)
                
                return (bach.value)
            elif bach.value=="Biosanitario":
                display(Lengua)
                display(Historia)
                display(Mates)
                display(Biologia)
                display(Quimica)
                display(Ingles)
                
                return (bach.value)
    
# linking button and function together using a button's method
button.on_click(on_button_clicked)
button2.on_click(on_button_clicked2)
button3.on_click(on_button_clicked3)
# displaying button and its output together
widgets.VBox([button,out])
widgets.VBox([button2])
widgets.VBox([button3])
x=widgets.VBox([out])
# Out:
# Text(value='', description='Name')
# DatePicker(value=None, description='Select Date')
# DatePicker(value=None, description='Select Date')
# Dropdown(description='Bachillerato:', options=('Sociales', 'Tecnologico', 'Biosanitario'), value=None)
# ...

# %%
dx=pd.read_csv("Clusteres_dfSOCIALES.csv")
dx.dtypes
# Out:
# cluster                int64
# Global_Mean          float64
# MediaLengua          float64
# Media_Mates          float64
# Media_Ingles         float64
# Media_Economia       float64
# Media_Geografia      float64
# Media_Historia       float64
# tipo_bachillerato      int64
# Count                  int64
# dtype: object

# %%
calendar
# Out:
# DatePicker(value=datetime.date(2021, 11, 22), description='Select Date')

# %%
Mates
Mates.value
# Out:
# BoundedFloatText(value=7.5, description='Nota Mates:', max=10.0, step=0.01)
# 7.5

# %%
out = widgets.Output()
Mates
Ingles
button2.on_click(on_button_clicked2)
widgets.VBox([button2,out])
# Out:
# BoundedFloatText(value=5.02, description='Nota Mates:', max=10.0, step=0.01)
# BoundedFloatText(value=5.0, description='Nota Ingles:', max=10.0, step=0.01)
# ...

# %%
text
calendar_INICIO
calendar_Examenes
bach
button = widgets.Button(description='Confirmar Bachillerato')
button2 = widgets.Button(description='Confirmar Notas')
button3 = widgets.Button(description='Obtener Perfil')
out = widgets.Output()
nptas=[]
def on_button_clicked3(_):
     
    with out:
        if len(nptas)!=0:
            print("")
            print("Evaluando")
        else:
            print("Confirma todos los inputs")
        
def on_button_clicked2(_):

      # "linking function with output"
    with out:
          # what happens when we press the button
        if (bach.value)=="Sociales":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates_sociales.value,"Mates_sociales"])
            nptas.extend([Economia.value,"Economia"])
            nptas.extend([Geografia.value,"Geografia"])
            nptas.extend([Ingles.value,"Ingles"])

        elif (bach.value)=="Tecnologico":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates.value,"Mates"])
            nptas.extend([Fisica.value,"Fisica"])
            nptas.extend([Dibujo.value,"Dibujo"])
            nptas.extend([Ingles.value,"Ingles"])

        elif (bach.value)=="Biosanitario":
            nptas.extend([Lengua.value,"Lengua"])
            nptas.extend([Historia.value,"Historia"])
            nptas.extend([Mates.value,"Mates"])
            nptas.extend([Biologia.value,"Biologia"])
            nptas.extend([Quimica.value,"Quimica"])
            nptas.extend([Ingles.value,"Ingles"])
       
#linking button and function together using a button's method

def on_button_clicked(_):
      # "linking function with output"
    with out:
          # what happens when we press the button
            clear_output()
            if bach.value=="Sociales":
                display(Lengua)
                display(Historia)
                display(Mates_sociales)
                display(Economia)
                display(Geografia)
                display(Ingles)
                
                return (bach.value)
            elif bach.value=="Tecnologico":
                display(Lengua)
                display(Historia)
                display(Mates)
                display(Fisica)
                display(Dibujo)
                display(Ingles)
                
                return (bach.value)
            elif bach.value=="Biosanitario":
                display(Lengua)
                display(Historia)
                display(Mates)
                display(Biologia)
                display(Quimica)
                display(Ingles)
                
                return (bach.value)
    
# linking button and function together using a button's method
button.on_click(on_button_clicked)
button2.on_click(on_button_clicked2)
button3.on_click(on_button_clicked3)
# displaying button and its output together
widgets.VBox([button,out])
widgets.VBox([button2])
widgets.VBox([button3])
x=widgets.VBox([out])
# Out:
# Text(value='', description='Name')
# DatePicker(value=None, description='Select Date')
# DatePicker(value=None, description='Select Date')
# Dropdown(description='Bachillerato:', index=2, options=('Sociales', 'Tecnologico', 'Biosanitario'), value='Bio…
# ...

# %%
# example of fitting a model on the scaled dataset
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from pickle import dump
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from pickle import load

# %%
dx= pd.DataFrame(np.asarray(nptas).reshape(-1,2))
dx=dx.set_index(1).T
notas=dx.iloc[0].values.tolist()
notas = [float(x) for x in notas]
media=sum(notas)/len(notas)
dx["media_troncales"]=media
df1=pd.read_csv("df_BACH__manerauno.csv")
col=df1.columns.tolist()[9:]
df1=df1[col]
df2=pd.concat([df1.head(1),dx], ignore_index=True).tail(1)
df2["tipo_bachillerato-Tecnologico"]=1
df2
# Out:
#   Lengua Mates Ingles Dibujo Fisica Historia  media_troncales  Biologia  \
# 1   10.0  10.0   10.0   10.0   10.0     10.0             10.0       NaN
#
#    Quimica  Mates_sociales  Economia  Geografia  tipo_bachillerato-Sanitario  \
# 1      NaN             NaN       NaN        NaN                          NaN
#
#    tipo_bachillerato-Sociales  tipo_bachillerato-Tecnologico
# 1                         NaN                              1

# %%
df2=pd.concat([df2.head(1),dx], ignore_index=True).tail(1)
cols = df2.columns.tolist()
df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
data=(df2.to_numpy())

data=data.reshape(1, -1)#si solo hay un dato
data=np.nan_to_num(data)
pipe = load(open('manera1_modelo3_kmeans22_pca1.pkl', 'rb'))
pcadf = pd.DataFrame(
    pipe["preprocessor"].transform(data),
    #columns=["component_1", "component_2", "component_3","component_4", "component_5","component_6"],
)

pcadf["predicted_cluster"] = pipe.predict(data)
pcadf.head()
# Out:
#           0  predicted_cluster
# 0 -0.610854                 20

# %%
from IPython.display import Markdown
# Using output to display Markdown
markdown_out = widgets.Output()
with markdown_out:
    display(Markdown('Slider value is ${}$'.format(slider.value)))
markdown_out
# Out:
# Output()

# %%
button = widgets.Button(description='My Button')
out = widgets.Output()
def on_button_clicked(_):
      # "linking function with output"
      with out:
          # what happens when we press the button
          clear_output()
          print('Something happens!')
# linking button and function together using a button's method
button.on_click(on_button_clicked)
# displaying button and its output together
widgets.VBox([button,out])

# %%
df = pd.read_csv('Bach_Sociales.csv')
df.head()
# Out:
#     año  mes  dia  hora  min   dateInt   Date_start_horario  \
# 0  2021    5   14     9    0  20210514  2021-05-14 09:00:00
# 1  2021    5   15    11    0  20210515  2021-05-15 11:00:00
# 2  2021    5   14    12    0  20210514  2021-05-14 12:00:00
# 3  2021    5   15    13    0  20210515  2021-05-15 13:00:00
# 4  2021    5   18     8    0  20210518  2021-05-18 08:00:00
#
#    Date_start_Examenes  days_left  Lengua  Mates_sociales  Ingles  Economia  \
# 0  2021-06-04 00:00:00         20    6.71            4.48    6.48      5.20
# 1  2021-06-08 00:00:00         23    6.37            8.91    6.54      4.75
# 2  2021-06-07 00:00:00         23    5.87            7.60    4.80      5.79
# 3  2021-06-03 00:00:00         18    4.45            5.10    9.96      7.85
# 4  2021-06-05 00:00:00         17    8.48            6.25    6.31      6.07
#
#    Geografia  Historia  media_troncales
# 0       6.00      5.72             5.76
# 1       5.35      7.59             6.58
# ...

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
@interact
def show_titles_more_than(column=['Lengua', 'Mates_sociales', 'Ingles', 'Economia', 'Geografia', 'Historia','media_troncales'], 
                          x=(0, 10, 0.5)):
    display(HTML(f'<h2>Showing articles with more than {x} {column}<h2>'))
    display(df.loc[df[column] > x, ['Lengua', 'Mates_sociales', 'Ingles', 'Economia', 'Geografia', 'Historia','media_troncales']])
# Out:
# interactive(children=(Dropdown(description='column', options=('Lengua', 'Mates_sociales', 'Ingles', 'Economia'…

# %%
df.set_index('Date_start_horario', inplace=True)

# %%
def print_articles_published(start_date, end_date):
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

_ = interact(print_articles_published,
             start_date=widgets.DatePicker(value=pd.to_datetime('2018-01-01')),
             end_date=widgets.DatePicker(value=pd.to_datetime('2019-01-01')))
# Out:
# interactive(children=(DatePicker(value=Timestamp('2018-01-01 00:00:00'), description='start_date'), DatePicker…

# %%
@interact
def clicked(a=ToggleButton()):
    print(a)
# Out:
# interactive(children=(ToggleButton(value=False, description='a'), Output()), _dom_classes=('widget-interact',)…

# %%
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

import cufflinks as cf
cf.go_offline(connected=True)
cf.set_config_file(colorscale='plotly', world_readable=True)

# Extra options
pd.options.display.max_rows = 30
pd.options.display.max_columns = 25

# Show all code cells outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
print("Qué bachillerato cursas;")
tipoBACH=int(input())



# import openpyxl and tkinter modules
    from openpyxl import *
    from tkinter import *

    # globally declare wb and sheet variable

    # opening the existing excel file
    wb = load_workbook('C:\\Users\\Javie\\Anaconda3\\Aplicaciones y Tendencias de Datos\\PROYECTONOTAS\\excel.xlsx')

    # create the sheet object
    sheet = wb.active


    def excel():

        # resize the width of columns in
        # excel spreadsheet
        sheet.column_dimensions['A'].width = 30
        sheet.column_dimensions['B'].width = 10
        sheet.column_dimensions['C'].width = 10
        sheet.column_dimensions['D'].width = 20
        sheet.column_dimensions['E'].width = 20
        sheet.column_dimensions['F'].width = 40
        sheet.column_dimensions['G'].width = 50

        # write given data to an excel spreadsheet
        # at particular location
        sheet.cell(row=1, column=1).value = "Nombre"
        sheet.cell(row=1, column=2).value = "Course"
        sheet.cell(row=1, column=3).value = "Semester"
        sheet.cell(row=1, column=4).value = "Form Number"
        sheet.cell(row=1, column=5).value = "Contact Number"
        sheet.cell(row=1, column=6).value = "Email id"
        sheet.cell(row=1, column=7).value = "Address"


    # Function to set focus (cursor)
    def focus1(event):
        # set focus on the course_field box
        course_field.focus_set()


    # Function to set focus
    def focus2(event):
        # set focus on the sem_field box
        sem_field.focus_set()


    # Function to set focus
    def focus3(event):
        # set focus on the form_no_field box
        form_no_field.focus_set()


    # Function to set focus
    def focus4(event):
        # set focus on the contact_no_field box
        contact_no_field.focus_set()


    # Function to set focus
    def focus5(event):
        # set focus on the email_id_field box
        email_id_field.focus_set()


    # Function to set focus
    def focus6(event):
        # set focus on the address_field box
        address_field.focus_set()


    # Function for clearing the
    # contents of text entry boxes
    def clear():

        # clear the content of text entry box
        name_field.delete(0, END)
        course_field.delete(0, END)
        sem_field.delete(0, END)
        form_no_field.delete(0, END)
        contact_no_field.delete(0, END)
        email_id_field.delete(0, END)
        address_field.delete(0, END)


    # Function to take data from GUI
    # window and write to an excel file
    def insert():

        # if user not fill any entry
        # then print "empty input"
        if (name_field.get() == "" and
            course_field.get() == "" and
            sem_field.get() == "" and
            form_no_field.get() == "" and
            contact_no_field.get() == "" and
            email_id_field.get() == "" and
            address_field.get() == ""):

            print("empty input")

        else:

            # assigning the max row and max column
            # value upto which data is written
            # in an excel sheet to the variable
            current_row = sheet.max_row
            current_column = sheet.max_column

            # get method returns current text
            # as string which we write into
            # excel spreadsheet at particular location
            sheet.cell(row=current_row + 1, column=1).value = name_field.get()
            sheet.cell(row=current_row + 1, column=2).value = course_field.get()
            sheet.cell(row=current_row + 1, column=3).value = sem_field.get()
            sheet.cell(row=current_row + 1, column=4).value = form_no_field.get()
            sheet.cell(row=current_row + 1, column=5).value = contact_no_field.get()
            sheet.cell(row=current_row + 1, column=6).value = email_id_field.get()
            sheet.cell(row=current_row + 1, column=7).value = address_field.get()

            # save the file
            wb.save('C:\\Users\\Javie\\Anaconda3\\Aplicaciones y Tendencias de Datos\\PROYECTONOTAS\\excel.xlsx')

            # set focus on the name_field box
            name_field.focus_set()

            # call the clear() function
            clear()


    # Driver code
    if __name__ == "__main__":

        # create a GUI window
        root = Tk()

        # set the background colour of GUI window
        root.configure(background='light green')

        # set the title of GUI window
        root.title("registration form")

        # set the configuration of GUI window
        root.geometry("500x300")

        excel()

        # create a Form label
        heading = Label(root, text="Form", bg="light green")

        # create a Name label
        name = Label(root, text="Name", bg="light green")

        # create a Course label
        course = Label(root, text="Course", bg="light green")

        # create a Semester label
        sem = Label(root, text="Semester", bg="light green")

        # create a Form No. label
        form_no = Label(root, text="Form No.", bg="light green")

        # create a Contact No. label
        contact_no = Label(root, text="Contact No.", bg="light green")

        # create a Email id label
        email_id = Label(root, text="Email id", bg="light green")

        # create a address label
        address = Label(root, text="Address", bg="light green")

        # grid method is used for placing
        # the widgets at respective positions
        # in table like structure .
        heading.grid(row=0, column=1)
        name.grid(row=1, column=0)
        course.grid(row=2, column=0)
        sem.grid(row=3, column=0)
        form_no.grid(row=4, column=0)
        contact_no.grid(row=5, column=0)
        email_id.grid(row=6, column=0)
        address.grid(row=7, column=0)

        # create a text entry box
        # for typing the information
        name_field = Entry(root)
        course_field = Entry(root)
        sem_field = Entry(root)
        form_no_field = Entry(root)
        contact_no_field = Entry(root)
        email_id_field = Entry(root)

        address_field = Entry(root)

        # bind method of widget is used for
        # the binding the function with the events

        # whenever the enter key is pressed
        # then call the focus1 function
        name_field.bind("<Return>", focus1)

        # whenever the enter key is pressed
        # then call the focus2 function
        course_field.bind("<Return>", focus2)

        # whenever the enter key is pressed
        # then call the focus3 function
        sem_field.bind("<Return>", focus3)

        # whenever the enter key is pressed
        # then call the focus4 function
        form_no_field.bind("<Return>", focus4)

        # whenever the enter key is pressed
        # then call the focus5 function
        contact_no_field.bind("<Return>", focus5)

        # whenever the enter key is pressed
        # then call the focus6 function
        email_id_field.bind("<Return>", focus6)

        # grid method is used for placing
        # the widgets at respective positions
        # in table like structure .
        name_field.grid(row=1, column=1, ipadx="100")
        course_field.grid(row=2, column=1, ipadx="100")
        sem_field.grid(row=3, column=1, ipadx="100")
        form_no_field.grid(row=4, column=1, ipadx="100")
        contact_no_field.grid(row=5, column=1, ipadx="100")
        email_id_field.grid(row=6, column=1, ipadx="100")
        address_field.grid(row=7, column=1, ipadx="100")

        # call excel function
        excel()

        # create a Submit Button and place into the root window
        submit = Button(root, text="Submit", fg="Black",
                                bg="Red", command=insert)
        submit.grid(row=8, column=1)

        # start the GUI
        root.mainloop()
